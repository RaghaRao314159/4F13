# %%
# 1. Uninstall jax and jaxlib (and pytensor if it's conflicting too)
# !pip uninstall -y GPy jax scipy jaxlib paramz pytensor > /dev/null 2>&1

# 2. Install the versions that GPy wants
# !pip install "numpy<2.0" "scipy<=1.12" GPy > /dev/null 2>&1

# !wget -q https://mlg.eng.cam.ac.uk/teaching/4f13/2526/cw/cw1a.mat > /dev/null
# !wget -q https://mlg.eng.cam.ac.uk/teaching/4f13/2526/cw/cw1e.mat > /dev/null
# !wget -q https://raw.githubusercontent.com/cambridge-mlg/4f13-courseworks/refs/heads/main/2526/cw1/gp.py > /dev/null

# %%
# !pip install "numpy<2.0"
# Out:
# Requirement already satisfied: numpy<2.0 in /usr/local/lib/python3.12/dist-packages (1.26.4)

# %%
import GPy
import numpy as np
import gp as cw1utils
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-1066246660.py in <cell line: 0>()
# ----> 1 import GPy
#       2 import numpy as np
#       3 import gp as cw1utils
#
# /usr/local/lib/python3.12/dist-packages/GPy/__init__.py in <module>
#       5 warnings.filterwarnings("ignore", category=DeprecationWarning)
#       6
# ----> 7 from . import core
#       8 from . import models
#       9 from . import mappings
#
# /usr/local/lib/python3.12/dist-packages/GPy/core/__init__.py in <module>
#      43 """
#      44
# ---> 45 from GPy.core.model import Model
#      46 from .parameterization import Param, Parameterized
#      47 from . import parameterization
#
# /usr/local/lib/python3.12/dist-packages/GPy/core/model.py in <module>
#       1 # Copyright (c) 2012-2014, GPy authors (see AUTHORS.txt).
#       2 # Licensed under the BSD 3-clause license (see LICENSE.txt)
# ----> 3 from .parameterization.priorizable import Priorizable
#       4 from paramz import Model as ParamzModel
#       5
#
# /usr/local/lib/python3.12/dist-packages/GPy/core/parameterization/__init__.py in <module>
#      13 # Licensed under the BSD 3-clause license (see LICENSE.txt)
#      14
# ---> 15 from .param import Param
#      16 from .parameterized import Parameterized
#      17 from . import transformations
#
# /usr/local/lib/python3.12/dist-packages/GPy/core/parameterization/param.py in <module>
#       2 # Licensed under the BSD 3-clause license (see LICENSE.txt)
#       3
# ----> 4 from paramz import Param
#       5 from .priorizable import Priorizable
#       6 from paramz.transformations import __fixed__
#
# /usr/local/lib/python3.12/dist-packages/paramz/__init__.py in <module>
#      32
#      33 from . import util
# ---> 34 from .model import Model
#      35 from .parameterized import Parameterized
#      36 from .param import Param
#
# /usr/local/lib/python3.12/dist-packages/paramz/model.py in <module>
#      36 from numpy.linalg.linalg import LinAlgError
#      37
# ---> 38 from . import optimization
#      39 from .parameterized import Parameterized
#      40 from .optimization.verbose_optimization import VerboseOptimization
#
# /usr/local/lib/python3.12/dist-packages/paramz/optimization/__init__.py in <module>
#      31 #===============================================================================
#      32
# ---> 33 from .optimization import *
#      34 from . import verbose_optimization
#
# /usr/local/lib/python3.12/dist-packages/paramz/optimization/optimization.py in <module>
#       3
#       4 import datetime as dt
# ----> 5 from scipy import optimize
#       6 from warnings import warn
#       7
#
# /usr/lib/python3.12/importlib/_bootstrap.py in _handle_fromlist(module, fromlist, import_, recursive)
#
# /usr/local/lib/python3.12/dist-packages/scipy/__init__.py in __getattr__(name)
#     132 def __getattr__(name):
#     133     if name in submodules:
# --> 134         return _importlib.import_module(f'scipy.{name}')
#     135     else:
#     136         try:
#
# /usr/lib/python3.12/importlib/__init__.py in import_module(name, package)
#      88                 break
#      89             level += 1
# ---> 90     return _bootstrap._gcd_import(name[level:], package, level)
#      91
#      92
#
# /usr/local/lib/python3.12/dist-packages/scipy/optimize/__init__.py in <module>
#     410 """  # noqa: E501
#     411
# --> 412 from ._optimize import *
#     413 from ._minimize import *
#     414 from ._root import *
#
# /usr/local/lib/python3.12/dist-packages/scipy/optimize/_optimize.py in <module>
#      33                    asarray, sqrt)
#      34 import numpy as np
# ---> 35 from scipy.linalg import cholesky, issymmetric, LinAlgError
#      36 from scipy.sparse.linalg import LinearOperator
#      37 from ._linesearch import (line_search_wolfe1, line_search_wolfe2,
#
# /usr/local/lib/python3.12/dist-packages/scipy/linalg/__init__.py in <module>
#     205
#     206 from ._misc import *
# --> 207 from ._cythonized_array_utils import *
#     208 from ._basic import *
#     209 from ._decomp import *
#
# _cythonized_array_utils.pyx in init scipy.linalg._cythonized_array_utils()
#
# ValueError: numpy.dtype size changed, may indicate binary incompatibility. Expected 96 from C header, got 88 from PyObject

# %%
### Arbitrary data, X and y
X = np.random.rand(20, 1) * 10  # 20 data points in 1D
y = np.sin(X) + (np.cos(X))**2 + np.random.randn(20, 1) * 0.5  # noisy opipbservations

# %% [markdown]
# ## Loading Matlab arrays in Python

# %%
import scipy.io as sio

# %%
data = sio.loadmat("cw1a.mat")  # Note this will throw an error because the file does not exist!

X = np.asarray(data["x"], dtype=float)
y = np.asarray(data["y"], dtype=float)

# %% [markdown]
# ## GP Model Definition with Various Kernels (using GPy):

# %% [markdown]
# ### Single kernels

# %% [markdown]
# Squared exponential (SE) isotropic

# %%
k = GPy.kern.RBF(input_dim=X.shape[1], lengthscale=1.0, variance=1.0)
m = GPy.models.GPRegression(X, y, k)
m.likelihood.variance = 1.0  # Note that this is the default value, so we don't strictly need to set it here unless we want a different initial value.

# %% [markdown]
# Periodic

# %%
k = GPy.kern.StdPeriodic(input_dim=X.shape[1], lengthscale=1.0, period=1.0, variance=1.0)
m = GPy.models.GPRegression(X, y, k)

# %% [markdown]
# SE Automatic Relevance Determination (ARD)

# %%
k = GPy.kern.RBF(input_dim=X.shape[1], ARD=True, lengthscale=1.0, variance=1.0)
m = GPy.models.GPRegression(X, y, k)

# %% [markdown]
# ### Combined kernels

# %% [markdown]
# Product of Periodic and SE Isotropic

# %%
k_per = GPy.kern.StdPeriodic(input_dim=X.shape[1], lengthscale=1.0, period=1.0, variance=1.0)
k_se  = GPy.kern.RBF(input_dim=X.shape[1], lengthscale=1.0, variance=1.0)
kernel = k_per * k_se
m = GPy.models.GPRegression(X, y, kernel)

# %% [markdown]
# Sum of two SE ARD Kernels

# %%
z = np.random.randn(4)
ell1 = np.exp(z[0])
sf1  = np.exp(z[1])
var1 = sf1**2

ell2 = np.exp(z[2])
sf2  = np.exp(z[3])
var2 = sf2**2

k1 = GPy.kern.RBF(input_dim=X.shape[1], ARD=True, lengthscale=ell1, variance=var1)
k2 = GPy.kern.RBF(input_dim=X.shape[1], ARD=True, lengthscale=ell2, variance=var2)
k  = k1 + k2

m = GPy.models.GPRegression(X, y, kernel=k)

# %% [markdown]
# ## GP Model Hyperparameter Optimisation using Marginal Likelihood

# %% [markdown]
# Once a GP regression model is specified, we can optimise its hyperparameters by minimising the negative log marginal likelihood (which is equivalent to maximising the likelihood of the data under the model.)

# %%
m.optimize(optimizer='lbfgsb', max_iters=2000, messages=False)

# %% [markdown]
# ## Utilities functions useful for producing figures to be included in report

# %%
cw1utils.print_model_summary(m)
cw1utils.print_model_marginal_likelihood(m)
cw1utils.plot_predictive_error_bars(m, X, y, "\n command\n another command")

# cw1utils.plot_2d_predictive(mA, mB, codeA=None, codeB=None, save_path=None)
# cw1utils.plot_sampled_functions(X, F, code_snippet, n_draws=3, save_path=None)
